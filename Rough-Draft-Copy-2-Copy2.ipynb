# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
# Import DataFrame with Pandas and view a piece of the DataFrame

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import sklearn
import matplotlib.pyplot as plt
# %matplotlib inline
kc_df = pd.read_csv('kc_house_data.csv')

# %%
kc_df.head()
# Take a peek at the data and see if anything does not look right off the start. I can already see a NaN value for waterfront and year renovated aswell.
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...      7        1180            0.0
# 1      7242     2.0         0.0   0.0  ...      7        2170          400.0
# 2     10000     1.0         0.0   0.0  ...      6         770            0.0
# 3      5000     1.0         0.0   0.0  ...      7        1050          910.0
# 4      8080     1.0         0.0   0.0  ...      8        1680            0.0
#
#   yr_built  yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0     1955           0.0    98178  47.5112 -122.257           1340        5650
# 1     1951        1991.0    98125  47.7210 -122.319           1690        7639
# 2     1933           NaN    98028  47.7379 -122.233           2720        8062
# 3     1965           0.0    98136  47.5208 -122.393           1360        5000
# 4     1987           0.0    98074  47.6168 -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
kc_df.info()
# 21 columns, 21597 data entries
#exploring column names and index range to see if there are missing values in the dataset. Also noting the type of data: integer, float, or object.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
# id               21597 non-null int64
# date             21597 non-null object
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# sqft_basement    21597 non-null object
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# dtypes: float64(8), int64(11), object(2)
# memory usage: 3.5+ MB

# %%
# My code above returned that I have missing values in "waterfront", "view", and "year renovated"
# Now I want to double check this using "isna()" 

kc_df.isna().sum()

#The output looks like both methods pointed out the same number of missing values in the dataset.
# Out:
# id                  0
# date                0
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# sqft_basement       0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# dtype: int64

# %%
# Do more Data Cleaning HERE - COME BACK

# %%
# I will be calculating the age of the house to try and find the oldest homes in the dataset.
# I will create a new variable called "house_age"

kc_df['house_age'] = 2019 - kc_df['yr_built']

# %%
kc_df.head()
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...        1180            0.0
# 1      7242     2.0         0.0   0.0  ...        2170          400.0
# 2     10000     1.0         0.0   0.0  ...         770            0.0
# 3      5000     1.0         0.0   0.0  ...        1050          910.0
# 4      8080     1.0         0.0   0.0  ...        1680            0.0
#
#    yr_built yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955          0.0    98178  47.5112 -122.257           1340
# 1      1951       1991.0    98125  47.7210 -122.319           1690
# 2      1933          NaN    98028  47.7379 -122.233           2720
# 3      1965          0.0    98136  47.5208 -122.393           1360
# 4      1987          0.0    98074  47.6168 -122.045           1800
#
#    sqft_lot15  house_age
# 0        5650         64
# 1        7639         68
# 2        8062         86
# 3        5000         54
# 4        7503         32
#
# [5 rows x 22 columns]

# %%
kc_df['house_age']
# Out:
# 0         64
# 1         68
# 2         86
# 3         54
# 4         32
# 5         18
# 6         24
# 7         56
# 8         59
# 9         16
# 10        54
# 11        77
# 12        92
# 13        42
# 14       119
# 15        40
# 16        25
# 17       103
# 18        98
# 19        50
# 20        72
# 21        51
# 22        24
# 23        34
# 24        34
# 25        78
# 26       104
# 27       110
# 28        71
# 29        14
#         ...
# 21567     76
# 21568     12
# 21569     10
# 21570     10
# 21571     13
# 21572     12
# 21573      9
# 21574     12
# 21575      5
# 21576     11
# 21577     13
# 21578     11
# 21579     13
# 21580      5
# 21581     12
# 21582      5
# 21583     16
# 21584     11
# 21585     11
# 21586      5
# 21587     16
# 21588      5
# 21589      5
# 21590     10
# 21591     11
# 21592     10
# 21593      5
# 21594     10
# 21595     15
# 21596     11
# Name: house_age, Length: 21597, dtype: int64

# %%
kc_df['house_age'].head()
# Out:
# 0    64
# 1    68
# 2    86
# 3    54
# 4    32
# Name: house_age, dtype: int64

# %%
#Now I am going to copy the kc_df to look at the data - called "newkc_df"

# %%
newkc_df = kc_df.copy()
newkc_df.head()

#Reference - https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.copy.html
# Out:
#            id        date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  10/13/2014  221900.0         3       1.00         1180
# 1  6414100192   12/9/2014  538000.0         3       2.25         2570
# 2  5631500400   2/25/2015  180000.0         2       1.00          770
# 3  2487200875   12/9/2014  604000.0         4       3.00         1960
# 4  1954400510   2/18/2015  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  sqft_above  sqft_basement  \
# 0      5650     1.0         NaN   0.0  ...        1180            0.0
# 1      7242     2.0         0.0   0.0  ...        2170          400.0
# 2     10000     1.0         0.0   0.0  ...         770            0.0
# 3      5000     1.0         0.0   0.0  ...        1050          910.0
# 4      8080     1.0         0.0   0.0  ...        1680            0.0
#
#    yr_built yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955          0.0    98178  47.5112 -122.257           1340
# 1      1951       1991.0    98125  47.7210 -122.319           1690
# 2      1933          NaN    98028  47.7379 -122.233           2720
# 3      1965          0.0    98136  47.5208 -122.393           1360
# 4      1987          0.0    98074  47.6168 -122.045           1800
#
#    sqft_lot15  house_age
# 0        5650         64
# 1        7639         68
# 2        8062         86
# 3        5000         54
# 4        7503         32
#
# [5 rows x 22 columns]

# %%
newkc_df.drop(columns = ['id', 'date', 'sqft_basement' ], inplace=True)
#removing objects ('date', 'sqft_basement') and 'id' column because this data is not neccessary for what I am looking at.

# %%
newkc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 19 columns):
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       19221 non-null float64
# view             21534 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# yr_built         21597 non-null int64
# yr_renovated     17755 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# house_age        21597 non-null int64
# dtypes: float64(8), int64(11)
# memory usage: 3.1 MB

# %%
# I want to check to see what all of the column variables look like based on price.
fig, axes = plt.subplots(nrows=1, ncols=6, figsize=(16,3))
for xcol, ax in zip(list(newkc_df)[1:7], axes):
                    newkc_df.plot(kind='scatter', x=xcol, y='price', ax=ax, alpha = 0.4, color = 'r');

# %%
fig, axes = plt.subplots(nrows=1, ncols=6, figsize=(16,3))
for xcol, ax in zip(list(newkc_df)[8:14], axes):
                    newkc_df.plot(kind='scatter', x=xcol, y='price', ax=ax, alpha = 0.4, color = 'r');

# %%
fig, axes = plt.subplots(nrows=1, ncols=6, figsize=(16,3))
for xcol, ax in zip(list(newkc_df)[15:20], axes):
                    newkc_df.plot(kind='scatter', x=xcol, y='price', ax=ax, alpha = 0.4, color = 'r');

# %%
# I see outliers so I am going to clean my data before looking at zipcodes, price, and house age.

# %%
#I am going to look at the missing values again and then replace them
newkc_df.isna().sum()
# Out:
# price               0
# bedrooms            0
# bathrooms           0
# sqft_living         0
# sqft_lot            0
# floors              0
# waterfront       2376
# view               63
# condition           0
# grade               0
# sqft_above          0
# yr_built            0
# yr_renovated     3842
# zipcode             0
# lat                 0
# long                0
# sqft_living15       0
# sqft_lot15          0
# house_age           0
# dtype: int64

# %%
newkc_df['yr_renovated'] = newkc_df['yr_renovated'].fillna(0)
newkc_df['view'] = newkc_df['view'].fillna(0)
newkc_df['waterfront'] = newkc_df['waterfront'].fillna(0)

newkc_df.isna().sum()

#https://datatofish.com/replace-nan-values-with-zeros/
# Out:
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# house_age        0
# dtype: int64

# %%
newkc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 19 columns):
# price            21597 non-null float64
# bedrooms         21597 non-null int64
# bathrooms        21597 non-null float64
# sqft_living      21597 non-null int64
# sqft_lot         21597 non-null int64
# floors           21597 non-null float64
# waterfront       21597 non-null float64
# view             21597 non-null float64
# condition        21597 non-null int64
# grade            21597 non-null int64
# sqft_above       21597 non-null int64
# yr_built         21597 non-null int64
# yr_renovated     21597 non-null float64
# zipcode          21597 non-null int64
# lat              21597 non-null float64
# long             21597 non-null float64
# sqft_living15    21597 non-null int64
# sqft_lot15       21597 non-null int64
# house_age        21597 non-null int64
# dtypes: float64(8), int64(11)
# memory usage: 3.1 MB

# %%
# Now I will look at

# %%
#new_df = kc_df[['house_age', 'price']].copy()
#newkc_df[['house_age', 'price']].copy()
newkc_df.groupby('house_age').median()
#just run to see if it works
#newkc_df.groupby("house_age").median()
#Here we are trying to get the average house price for every house age (1, 2, 3, 4 (years old), etc.)
# Out:
#               price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# house_age
# 4          629500.0       4.0      2.750       2590.0    4383.0     2.0
# 5          599000.0       4.0      2.500       2650.0    4926.0     2.0
# 6          565000.0       4.0      2.500       2580.0    5205.0     2.0
# 7          448475.0       4.0      2.500       2237.5    5005.5     2.0
# 8          440000.0       3.0      2.500       2270.0    4899.0     2.0
# 9          448500.0       3.0      2.500       2080.0    4533.0     2.0
# 10         416375.0       3.0      2.500       1722.0    3316.0     2.0
# 11         500000.0       3.0      2.500       1780.0    2750.0     2.0
# 12         480000.0       3.0      2.500       1980.0    3826.0     2.0
# 13         511000.0       4.0      2.500       2450.0    5000.0     2.0
# 14         486000.0       3.0      2.500       2258.5    4756.0     2.0
# 15         507000.0       4.0      2.500       2400.0    5194.0     2.0
# 16         453000.0       4.0      2.500       2335.0    5656.5     2.0
# 17         447500.0       4.0      2.500       2420.0    6039.5     2.0
# 18         585000.0       4.0      2.500       2680.0    6353.0     2.0
# 19         544250.0       4.0      2.500       2485.0    6172.0     2.0
# 20         500000.0       4.0      2.500       2403.0    6466.0     2.0
# 21         500000.0       4.0      2.500       2460.0    7904.0     2.0
# 22         515000.0       4.0      2.500       2360.0    8820.0     2.0
# 23         540250.0       4.0      2.500       2285.0    9671.5     2.0
# 24         496000.0       3.0      2.500       2270.0    9624.0     2.0
# 25         439000.0       3.0      2.500       2040.0    9253.0     2.0
# 26         435000.0       3.0      2.500       2345.0    9070.5     2.0
# 27         472500.0       3.0      2.500       2250.0    9221.0     2.0
# 28         534150.0       3.0      2.500       2415.0    9853.5     2.0
# 29         455000.0       3.0      2.500       2390.0    9600.0     2.0
# 30         490000.0       3.0      2.500       2275.0    9916.0     2.0
# 31         500000.0       3.0      2.500       2220.0    9859.5     2.0
# 29             9137.0
# 30             9730.0
# 31             9600.0
# 32             8884.5
# 33             8780.0
# ...               ...
# 90             4780.0
# 91             5080.0
# 92             4917.0
# 93             4725.0
# 94             5000.0
# 95             4800.0
# 96             5000.0
# 97             5000.0
# 98             4826.0
# 99             5378.5
# 100            4715.0
# 101            5030.0
# 102            5000.0
# 103            5000.0
# 104            5000.0
# 105            4530.0
# 106            5000.0
# 107            4590.0
# 108            4750.0
# 109            4500.0
# 110            4450.0
# 111            4547.5
# 112            4800.0
# 113            4434.5
# 114            4800.0
# 115            4109.0
# 116            4553.5
# 117            4264.0
# 118            4000.0
# 119            4850.0
#
# [116 rows x 18 columns]

# %%
kc_df['zipcode'].value_counts()

# %%
kc_df['zipcode'].describe()

# %%
sns.set(rc={'figure.figsize': (16,12)})
new_df = kc_df[['house_age', 'price']].copy().rename(columns = {'median': 'median price $'})
new_df.groupby("house_age").median().plot(y='price', kind = 'bar')

#Now I wan't to visualize the data and graph it with a bar graph. 

#new_df.head()
#new_df.groupby("house_age").median().plot(y='price', kind = 'bar')
#new_df.groupby('house_age')['price'].describe().rename(columns = {'count': '# of Houses',
                        #'mean': 'Mean', 'std': 'Variation', 'min': 'Min', 
                        #'25%': '1st Qtl','50%': 'Median', '75%': '3rd Qtl',
                        #'max': 'Max', 'price': 'Price $'})

# %%
#fig = plt.figure(figsize=(10,4))
#
#title = fig.suptitle("House age value in King County", fontsize=14)
#fig.subplots_adjust(top=0.85, wspace=0.35, )
#
#ax1 = fig.add_subplot(1,2,1)
#ax1.set_title("Impact of House Age on Price", fontsize=12)
#ax1.tick_params(labelsize=12)
#sns.barplot(x='house_age', y='price', data=new_df, ax=ax1);
#ax1.set_ylabel("Median Price $",)
#ax1.set_xlabel("house_age")
#ax2 = fig.add_subplot(1,2,2)
#ax2.set_title("Impact of Grade Value on Price per Sq Foot",)
#
#sns.barplot(x='house_age', y='price', ax=ax2, data=new_df,);
#ax2.set_ylabel("Median Price Per Sq Ft($ / Sqft)");
#ax2.set_xlabel("house_age");

# %%
#so here we need to change to newkc_df

# %%
red = dict(markerfacecolor='r')
sns.set(rc={'figure.figsize': (16,12)})
kc_df.boxplot(by='zipcode', column='price', fontsize = 12, rot = 90, flierprops = red);

plt.title('Boxplots of Price Variation ($) Grouped by Zipcode', fontsize = 16)

plt.xlabel('King County Zipcodes', fontsize = 12);
plt.ylabel('Price, $', fontsize = 12);
plt.savefig("Price vs Zip.png")


# Reference: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.boxplot.html

# %%
green = dict(markerfacecolor='g')
sns.set(rc={'figure.figsize': (16,12)})
kc_df.boxplot(by='zipcode', column='house_age', fontsize = 12, rot = 90, flierprops = green);

plt.title('Boxplots of House Age Variation Grouped by Zipcode', fontsize = 16)

plt.xlabel('King County Zipcodes', fontsize = 12);
plt.ylabel('Age', fontsize = 12);
plt.savefig("House Age vs Zip.png")


# Reference: https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.boxplot.html

# %%
#98102 Zipcode average house age is between 90-95 years old. Yet, on average, the house prices range from 50k-100k.

# %%
kc_df.columns

# %%
#drop waterfront, year renovated, view

feature_columns = ['bedrooms', 'bathrooms', 'sqft_living',
       'sqft_lot', 'floors', 'condition', 'grade',
       'sqft_above', 'sqft_basement', 'yr_built', 'zipcode',
       'lat', 'long', 'sqft_living15', 'sqft_lot15', 'house_age']
x = kc_df[feature_columns]
y = kc_df["price"]

kc_df.head()

# %%
#MODELING
#datasets
#kc_df
#new_df (change name)
#filter outliers from

# %%
#1st - kc_df - added new variable to original df
#2nd - new_df - cleaned data from original df
#3rd - make another df from example - 58 on
